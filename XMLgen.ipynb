# %%
import string
from hashlib import sha1
from datetime import datetime
import pickle
import ast
from jinja2 import Environment, FileSystemLoader,Template
import pandas as pd
import numpy as np
from tqdm import tqdm

data=pd.read_csv("nochangePSU.csv",index_col=0,na_values=['#VALUE!'])

# %%
data
# Out:
#      Unnamed: 0.1                    CIN             CIN telugu  \
# 0               0  L74899DL1964GOI004281  L74899DL1964GOI004281
# 1               1  L23220MH1952GOI008931  L23220MH1952GOI008931
# 2               2  L23109WB1973GOI028844  L23109WB1973GOI028844
# 3               3  L40200DL1984GOI018976  L40200DL1984GOI018976
# 4               4  L23201MH1952GOI008858  L23201MH1952GOI008858
# ..            ...                    ...                    ...
# 352           352  U45200MH2006PLC160164  U45200MH2006PLC160164
# 353           353  U64200MH2003PLC143200  U64200MH2003PLC143200
# 354           354  L23200GJ1969PLC001569  L23200GJ1969PLC001569
# 355           355  U93090TN1960PLC004355  U93090TN1960PLC004355
# 356           356  U62100DL1992GOI048581  U62100DL1992GOI048581
#
#                                    Company Name  \
# 0              BHARAT HEAVY ELECTRICALS LIMITED
# 1          BHARAT PETROLEUM CORPORATION LIMITED
# 2                                COAL INDIA LTD
# 3                          GAIL (INDIA) LIMITED
# 4       HINDUSTAN PETROLEUM CORPORATION LIMITED
# ..                                          ...
# 352        MUMBAI INTERNATIONAL AIRPORT LIMITED
# 353                      VSNL BROADBAND LIMITED
# 354  INDIAN PETROCHEMICALS CORPORATION LIMITE D
# 355                                 HTL LIMITED
# 356                           AIR INDIA LIMITED
#
#                                  company_name_tel Company Status  \
# 0               భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్         Active
# 1           భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్         Active
# 2                            కోల్ ఇండియా లిమిటెడ్         Active
# 3                        గెయిల్ (ఇండియా) లిమిటెడ్         Active
# 4     హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్         Active
# ..                                            ...            ...
# 352       ముంబై ఇంటర్నేషనల్ ఎయిర్‌పోర్ట్ లిమిటెడ్         Active
# 353        వి.ఎస్.ఎన్.ఎల్ బ్రాడ్‌బ్యాండ్ లిమిటెడ్    Amalgamated
# 354  ఇండియన్ పెట్రోకెమికల్స్ కార్పొరేషన్ లిమిటెడ్    Amalgamated
# 355                          హెచ్.టి.ఎల్ లిమిటెడ్         Active
# 356                         ఎయిర్ ఇండియా లిమిటెడ్    Amalgamated
#
#     Company_Status_telugu            RoC      RoC_telugu  reg_number  ...  \
# 0                చురుకుగా      RoC-Delhi      RoC-ఢిల్లీ      4281.0  ...
# 1                చురుకుగా     RoC-Mumbai      RoC-ముంబయి      8931.0  ...
# 2                చురుకుగా    RoC-Kolkata    RoC-కోల్‌కతా     28844.0  ...
# 3                చురుకుగా      RoC-Delhi      RoC-ఢిల్లీ     18976.0  ...
# 4                చురుకుగా     RoC-Mumbai      RoC-ముంబయి      8858.0  ...
# ..                    ...            ...             ...         ...  ...
# 352              చురుకుగా     RoC-Mumbai      RoC-ముంబయి    160164.0  ...
# 353         సమ్మిళితమైంది     RoC-Mumbai      RoC-ముంబయి    143200.0  ...
# 354              సమ్మేళనం  RoC-Ahmedabad  RoC-అహ్మదాబాద్      1569.0  ...
# 355              చురుకుగా    RoC-Chennai      RoC-చెన్నై      4355.0  ...
# 356         సమ్మిళితమైంది      RoC-Delhi      RoC-ఢిల్లీ     48581.0  ...
#
#                                       Owner_telugu  \
# 0                          భారత ప్రభుత్వం (63.17%)
# 1                          భారత ప్రభుత్వం (52.98%)
# 2                          భారత ప్రభుత్వం (66.13%)
# 3                          భారత ప్రభుత్వం (51.83%)
# 4    ఆయిల్ అండ్ నేచురల్ గ్యాస్ కార్పొరేషన్ (54.9%)
# ..                                             ...
# 352                                            NaN
# 353                                            NaN
# 354                                            NaN
# 355                                            NaN
# 356                                            NaN
#
#                                        new history eng  \
# 0    BHEL was established in 1956 ushering in the H...
# 1    The company today known as BPCL started off as...
# 2    Coal mining in India had primarily been a priv...
# 3    GAIL (India) Limited was incorporated in Augus...
# 4    HPCL was incorporated in 1974 after the takeov...
# ..                                                 ...
# 352  A 2017 stamp sheet dedicated to the 75th anniv...
# 353  The business was founded as Videsh Sanchar Nig...
# 354  IPCL was established on 22 March 1969, as a Go...
# 355                                                NaN
# 356  Air India Limited is a private entity and is u...
#
#                                        new_history_tel  \
# 0    బి.హెచ్.ఈ.ఎల్ భారతదేశంలో 1956 సంవత్సరంలో స్థాప...
# 1    భారతదేశంలోని బ్రిటిష్ వలస పాలనలో అస్సాం, బర్మా...
# 2    భారతదేశంలో బొగ్గు తవ్వకం ప్రాథమికంగా ప్రైవేట్ ...
# 3    జి.ఎ.ఐ.ఎల్. (ఇండియా) లిమిటెడ్‌ ఆగష్టు 1984లో ప...
# 4    1974లో ఎస్సో (భారతదేశంలో అండర్‌టేకింగ్‌ల స్వాధ...
# ..                                                 ...
# 352  ఛత్రపతి శివాజీ అంతర్జాతీయ విమానాశ్రయం తమ 75 వ ...
# 353  ఈ వ్యాపారాన్ని 1986లో విదేశ్ సంచార్ నిగమ్ లిమి...
# 354  1969 మార్చి 22న భారతదేశంలో పెట్రోకెమికల్ పరిశ్...
# 355                                                NaN
# 356  ఎయిరిండియా లిమిటెడ్ ఒక ప్రైవేట్ సంస్థ, టాటా గ్...
#
#                                         operations eng  \
# 0    BHEL-built 6,000 HP electric locomotive WAG9H....
# 1    Bharat Petroleum operates the following refine...
# 2    CIL is the largest coal producing company in t...
# 3    GAIL has built a network of trunk pipelines co...
# 4    HPCL operates two major refineries producing a...
# ..                                                 ...
# 352                                                NaN
# 353  Tata Communications offers Ethernet services t...
# 354                                                NaN
# 355                                                NaN
# 356  Upon completion of the merger on 26 February 2...
#
#                                         operations_tel wikidata  \
# 0    బి.హెచ్.ఈ.ఎల్ 6,000 హెచ్.పి. ఎలక్ట్రిక్ లోకోమో...  Q854820
# 1    భారత్ పెట్రోలియం కింది రిఫైనరీలను నిర్వహిస్తోం...      NaN
# 2    సి.ఐ.ఎల్. ప్రపంచంలోనే అతిపెద్ద బొగ్గు ఉత్పత్తి...      NaN
# 3    గెయిల్ దాదాపు 13722 కి.మీ పొడవున ట్రంక్ పైప్‌ల...      NaN
# 4    హెచ్.పి.సి.ఎల్. అనేక రకాల పెట్రోలియం ఇంధనాలు, ...      NaN
# ..                                                 ...      ...
# 352                                                NaN      NaN
# 353  టాటా కమ్యూనికేషన్స్ ఈథర్ నెట్ సేవలను అందిస్తుం...      NaN
# 354                                                NaN      NaN
# 355                                                NaN      NaN
# 356  26 ఫిబ్రవరి 2011 న విలీనం పూర్తయిన తరువాత, ఇప్...      NaN
#
#                                               wiki_url  BSE_code   NSE_code  \
# 0    https://en.wikipedia.org/wiki/Bharat_Heavy_Ele...  500103.0       BHEL
# 1    https://en.wikipedia.org/wiki/Bharat_Petroleum...  500547.0       BPCL
# 2             https://en.wikipedia.org/wiki/Coal_India  533278.0  COALINDIA
# 3                   https://en.wikipedia.org/wiki/GAIL  532155.0       GAIL
# 4    https://en.wikipedia.org/wiki/Hindustan_Petrol...  500104.0  HINDPETRO
# ..                                                 ...       ...        ...
# 352  https://en.wikipedia.org/wiki/Chhatrapati_Shiv...       NaN        NaN
# 353  https://en.wikipedia.org/wiki/Tata_Communications       NaN        NaN
# 354  https://en.wikipedia.org/wiki/Indian_Petrochem...       NaN        NaN
# 355                                                NaN       NaN        NaN
# 356    https://en.wikipedia.org/wiki/Air_India_Limited       NaN        NaN
#
#                              logo
# 0                   BHEL_logo.svg
# 1       Bharat_Petroleum_Logo.svg
# 2             Coal_India_Logo.svg
# 3                        GAIL.svg
# 4    Hindustan_Petroleum_Logo.svg
# ..                            ...
# 352                           NaN
# 353            Tata_Comm_logo.svg
# 354                           NaN
# 355                           NaN
# 356            Air_India_Logo.svg
#
# [357 rows x 118 columns]

# %%
company = data.copy()
data.set_index('company_name_tel',inplace=True)
company.reset_index(inplace=True)
tewiki = '''<mediawiki xml:lang="te" version="0.10" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.mediawiki.org/xml/export-0.10/">


<siteinfo>

<sitename>tewiki</sitename>

<dbname>indicwiki</dbname>

<base>https://tewiki.iiit.ac.in/index.php?title=%E0%B0%AE%E0%B1%8A%E0%B0%A6%E0%B0%9F%E0%B0%BF_%E0%B0%AA%E0%B1%87%E0%B0%9C%E0%B1%80</base>

<generator>MediaWiki 1.34.0</generator>

<case>first-letter</case>


<namespaces>

<namespace case="first-letter" key="-2">మీడియా</namespace>

<namespace case="first-letter" key="-1">ప్రత్యేక</namespace>

<namespace case="first-letter" key="0"/>

<namespace case="first-letter" key="1">చర్చ</namespace>

<namespace case="first-letter" key="2">వాడుకరి</namespace>

<namespace case="first-letter" key="3">వాడుకరి చర్చ</namespace>

<namespace case="first-letter" key="4">Project</namespace>

<namespace case="first-letter" key="5">Project చర్చ</namespace>

<namespace case="first-letter" key="6">దస్త్రం</namespace>

<namespace case="first-letter" key="7">దస్త్రంపై చర్చ</namespace>

<namespace case="first-letter" key="8">మీడియావికీ</namespace>

<namespace case="first-letter" key="9">మీడియావికీ చర్చ</namespace>

<namespace case="first-letter" key="10">మూస</namespace>

<namespace case="first-letter" key="11">మూస చర్చ</namespace>

<namespace case="first-letter" key="12">సహాయం</namespace>

<namespace case="first-letter" key="13">సహాయం చర్చ</namespace>

<namespace case="first-letter" key="14">వర్గం</namespace>

<namespace case="first-letter" key="15">వర్గం చర్చ</namespace>

<namespace case="first-letter" key="106">Form</namespace>

<namespace case="first-letter" key="107">Form talk</namespace>

<namespace case="first-letter" key="120">Item</namespace>

<namespace case="first-letter" key="121">Item talk</namespace>

<namespace case="first-letter" key="122">Property</namespace>

<namespace case="first-letter" key="123">Property talk</namespace>

<namespace case="first-letter" key="482">Config</namespace>

<namespace case="first-letter" key="483">Config talk</namespace>

<namespace case="first-letter" key="710">TimedText</namespace>

<namespace case="first-letter" key="711">TimedText talk</namespace>

<namespace case="first-letter" key="828">మాడ్యూల్</namespace>

<namespace case="first-letter" key="829">మాడ్యూల్ చర్చ</namespace>

<namespace case="first-letter" key="2300">Gadget</namespace>

<namespace case="first-letter" key="2301">Gadget talk</namespace>

<namespace case="case-sensitive" key="2302">Gadget definition</namespace>

<namespace case="case-sensitive" key="2303">Gadget definition talk</namespace>

<namespace case="first-letter" key="2600">Topic</namespace>

<namespace case="first-letter" key="3022">Tewiki</namespace>

<namespace case="first-letter" key="3023">Tewiki talk</namespace>

</namespaces>

</siteinfo>'''


# 717000 -  => companies's articles

page_id = 721000

user_id ="18853"
username ="Vardhan"

# Funtions to write page to file object
def sha36(page_id):
	page_id = str(page_id).encode('utf-8')
	sha16 =sha1(page_id).hexdigest()
	sha10 =int(sha16, 16)

	chars =[]
	alphabets = string.digits +string.ascii_lowercase
	while sha10>0:
		sha10, r = divmod(sha10, 36)
		chars.append(alphabets[r])
	
	return ''.join(reversed(chars))

# Function to replace possible Entity references
def clean(text):
	text = text.replace('&',"&amp;")
	text = text.replace('<',"&lt;")
	text = text.replace('>',"&gt;")
	text = text.replace('"',"&quot;")
	text = text.replace("'","&apos;")

	return text

def writePage(title, wikiText, fobj):
	global user_id, username, page_id

	pglen = len(wikiText)
	time =datetime.now().strftime("%Y-%m-%dT%H-%M-%SZ")
	
	curPage ='''\n\n
	<page>
		<title>''' +clean(title) +'''</title>
		<ns>0</ns>
		<id>''' +str(page_id) +'''</id>
		<revision>
			<id>''' +str(page_id) +'''</id>
			<timestamp>'''+time+'''</timestamp>
			<contributor>
				<username>''' +username +'''</username>
				<id>''' +str(user_id) +'''</id>
			</contributor>
			<comment>xmlpage created</comment>
			<model>wikitext</model>
			<format>text/x-wiki</format>
			<text xml:space="preserve" bytes="''' +str(pglen) +'''">
			\n''' + clean(wikiText) +'''
			</text>
			<sha1>''' +sha36(page_id) +'''</sha1>
		</revision>
	</page>
	\n\n'''

	fobj.write(curPage)
	page_id += 1
	return


def getData(B):
    row_dict = {}
    cmp_dict = dict(data.loc[B])
    for k,v in zip(cmp_dict,cmp_dict.values()):
        try:
            if not pd.isna(v):
                row_dict["_".join(k.split(' '))] = str(v)
            else:
                row_dict["_".join(k.split(' '))] = 'NaN'
        except:
            if not v.empty:
                row_dict["_".join(k.split(' '))] = str(v)
            else:
                row_dict["_".join(k.split(' '))] = 'NaN'
    row_dict['company_name_tel'] = B
    return row_dict


file_loader = FileSystemLoader('./')
env = Environment(loader=file_loader)
env.globals.update(zip=zip)
template = env.get_template('sample.j2')

fname="BHEL.xml"
fobj = open('BHEL.xml', 'w',encoding='utf-8')
# fobj = open('birds.xml', 'w')
fobj.write(tewiki)


# for i in tqdm(range(birds.shape[0])):
for i in tqdm(range(1)):
    title = company['company_name_tel'][i]
    text = template.render(getData(title)) 

    writePage(title, text, fobj)



fobj.write('</mediawiki>')
fobj.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ea3a47d1b817> in <module>
#       1 company = data.copy()
# ----> 2 data.set_index('company_name_tel',inplace=True)
#       3 company.reset_index(inplace=True)
#       4 tewiki = '''<mediawiki xml:lang="te" version="0.10" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://www.mediawiki.org/xml/export-0.10/">
#       5
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['company_name_tel'] are in the columns"

# %%
d = pd.read_csv('no_name.csv',index_col=0)

# %%
a = d[['Name']]

# %%
a.to_csv('name.csv')

# %%
data
# Out:
#                                              Unnamed: 0  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                   0.0
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్               1.0
# కోల్ ఇండియా లిమిటెడ్                                2.0
# గెయిల్ (ఇండియా) లిమిటెడ్                            3.0
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్         4.0
# ...                                                 ...
# హెచ్.టి.ఎల్ లిమిటెడ్                              355.0
# ఎయిర్ ఇండియా లిమిటెడ్                             356.0
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                                                CIN  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            L74899DL1964GOI004281
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        L23220MH1952GOI008931
# కోల్ ఇండియా లిమిటెడ్                         L23109WB1973GOI028844
# గెయిల్ (ఇండియా) లిమిటెడ్                     L40200DL1984GOI018976
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  L23201MH1952GOI008858
# ...                                                            ...
# హెచ్.టి.ఎల్ లిమిటెడ్                         U93090TN1960PLC004355
# ఎయిర్ ఇండియా లిమిటెడ్                        U62100DL1992GOI048581
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
#
#                                                         CIN telugu  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            L74899DL1964GOI004281
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        L23220MH1952GOI008931
# కోల్ ఇండియా లిమిటెడ్                         L23109WB1973GOI028844
# గెయిల్ (ఇండియా) లిమిటెడ్                     L40200DL1984GOI018976
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  L23201MH1952GOI008858
# ...                                                            ...
# హెచ్.టి.ఎల్ లిమిటెడ్                         U93090TN1960PLC004355
# ఎయిర్ ఇండియా లిమిటెడ్                        U62100DL1992GOI048581
# NaN                                                            NaN
# NaN                                                            NaN
# NaN                                                            NaN
#
#                                                                         Company Name  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                   BHARAT HEAVY ELECTRICALS LIMITED
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్           BHARAT PETROLEUM CORPORATION LIMITED
# కోల్ ఇండియా లిమిటెడ్                                                 COAL INDIA LTD
# గెయిల్ (ఇండియా) లిమిటెడ్                                        GAIL (INDIA) LIMITED
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  HINDUSTAN PETROLEUM CORPORATION LIMITED
# ...                                                                              ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                     HTL LIMITED
# ఎయిర్ ఇండియా లిమిటెడ్                                              AIR INDIA LIMITED
# NaN                                                                              NaN
# NaN                                                                              NaN
# NaN                                                                              NaN
#
#                                             Company Status  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                   Active
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్               Active
# కోల్ ఇండియా లిమిటెడ్                                Active
# గెయిల్ (ఇండియా) లిమిటెడ్                            Active
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్         Active
# ...                                                    ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                Active
# ఎయిర్ ఇండియా లిమిటెడ్                          Amalgamated
# NaN                                                    NaN
# NaN                                                    NaN
# NaN                                                    NaN
#
#                                             Company_Status_telugu  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                        చురుకుగా
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్                    చురుకుగా
# కోల్ ఇండియా లిమిటెడ్                                     చురుకుగా
# గెయిల్ (ఇండియా) లిమిటెడ్                                 చురుకుగా
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్              చురుకుగా
# ...                                                           ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                     చురుకుగా
# ఎయిర్ ఇండియా లిమిటెడ్                               సమ్మిళితమైంది
# NaN                                                           NaN
# NaN                                                           NaN
# NaN                                                           NaN
#
#                                                      RoC    RoC_telugu  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్              RoC-Delhi    RoC-ఢిల్లీ
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్         RoC-Mumbai    RoC-ముంబయి
# కోల్ ఇండియా లిమిటెడ్                         RoC-Kolkata  RoC-కోల్‌కతా
# గెయిల్ (ఇండియా) లిమిటెడ్                       RoC-Delhi    RoC-ఢిల్లీ
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్   RoC-Mumbai    RoC-ముంబయి
# ...                                                  ...           ...
# హెచ్.టి.ఎల్ లిమిటెడ్                         RoC-Chennai    RoC-చెన్నై
# ఎయిర్ ఇండియా లిమిటెడ్                          RoC-Delhi    RoC-ఢిల్లీ
# NaN                                                  NaN           NaN
# NaN                                                  NaN           NaN
# NaN                                                  NaN           NaN
#
#                                              reg_number  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                4281.0
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్            8931.0
# కోల్ ఇండియా లిమిటెడ్                            28844.0
# గెయిల్ (ఇండియా) లిమిటెడ్                        18976.0
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్      8858.0
# ...                                                 ...
# హెచ్.టి.ఎల్ లిమిటెడ్                             4355.0
# ఎయిర్ ఇండియా లిమిటెడ్                           48581.0
# NaN                                                 NaN
# NaN                                                 NaN
# NaN                                                 NaN
#
#                                              Registration Number telugu  ...  \
# company_name_tel                                                         ...
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                                4281.0  ...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్                            8931.0  ...
# కోల్ ఇండియా లిమిటెడ్                                            28844.0  ...
# గెయిల్ (ఇండియా) లిమిటెడ్                                        18976.0  ...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్                      8858.0  ...
# ...                                                                 ...  ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                             4355.0  ...
# ఎయిర్ ఇండియా లిమిటెడ్                                           48581.0  ...
# NaN                                                                 NaN  ...
# NaN                                                                 NaN  ...
# NaN                                                                 NaN  ...
#
#                                                                                   Owner  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                        \tGovernment of India (63.17%)
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్                      Government of India (52.98%)
# కోల్ ఇండియా లిమిటెడ్                                       Government of India (66.13%)
# గెయిల్ (ఇండియా) లిమిటెడ్                                   Government of India (51.83%)
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  Oil and Natural Gas Corporation (54.9%)[3]
# ...                                                                                 ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                NaN
# ఎయిర్ ఇండియా లిమిటెడ్                                                               NaN
# NaN                                                                                 NaN
# NaN                                                                                 NaN
# NaN                                                                                 NaN
#
#                                                                               Owner_telugu  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                                  భారత ప్రభుత్వం (63.17%)
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్                              భారత ప్రభుత్వం (52.98%)
# కోల్ ఇండియా లిమిటెడ్                                               భారత ప్రభుత్వం (66.13%)
# గెయిల్ (ఇండియా) లిమిటెడ్                                           భారత ప్రభుత్వం (51.83%)
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  ఆయిల్ అండ్ నేచురల్ గ్యాస్ కార్పొరేషన్ (54.9%)
# ...                                                                                    ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                   NaN
# ఎయిర్ ఇండియా లిమిటెడ్                                                                  NaN
# NaN                                                                                    NaN
# NaN                                                                                    NaN
# NaN                                                                                    NaN
#
#                                                                                        history  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            బి.హెచ్.ఈ.ఎల్ భారతదేశంలో హెవీ ఎలక్ట్రికల్ ఎక్వ...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        1891 నుండి 1976 వరకుభారతదేశంలోని బ్రిటిష్ వలస ...
# కోల్ ఇండియా లిమిటెడ్                         భారతదేశంలో బొగ్గు తవ్వకం ప్రాథమికంగా ప్రైవేట్ ...
# గెయిల్ (ఇండియా) లిమిటెడ్                     GAIL (India) Limited ఆగష్టు 1984లో పెట్రోలియం ...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  విశాఖపట్నంలోని యారాడ కొండ నుండి HPCL దృశ్యం197...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                                                                      NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                                                                new history eng  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            బి.హెచ్.ఈ.ఎల్ was established in 1956 ushering...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        The company today known as BPCL started off as...
# కోల్ ఇండియా లిమిటెడ్                         Coal mining in India had primarily been a priv...
# గెయిల్ (ఇండియా) లిమిటెడ్                     GAIL (India) Limited was incorporated in Augus...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  HPCL was incorporated in 1974 after the takeov...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                        Air India Limited is a private entity and is u...
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                                                                new_history_tel  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            బి.హెచ్.ఈ.ఎల్ భారతదేశంలో 1956 సంవత్సరంలో స్థాప...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        భారతదేశంలోని బ్రిటిష్ వలస పాలనలో అస్సాం, బర్మా...
# కోల్ ఇండియా లిమిటెడ్                         భారతదేశంలో బొగ్గు తవ్వకం ప్రాథమికంగా ప్రైవేట్ ...
# గెయిల్ (ఇండియా) లిమిటెడ్                      GAIL (ఇండియా) లిమిటెడ్‌ ఆగష్టు 1984లో పెట్రోల...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  1974లో ఎస్సో (భారతదేశంలో అండర్‌టేకింగ్‌ల స్వాధ...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                        ఎయిరిండియా లిమిటెడ్ ఒక ప్రైవేట్ సంస్థ, టాటా గ్...
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                                                                 operations eng  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            బి.హెచ్.ఈ.ఎల్-built 6,000 HP electric locomoti...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        Bharat Petroleum operates the following refine...
# కోల్ ఇండియా లిమిటెడ్                         CIL is the largest coal producing company in t...
# గెయిల్ (ఇండియా) లిమిటెడ్                     GAIL has built a network of trunk pipelines co...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  HPCL operates two major refineries producing a...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                        Upon completion of the merger on 26 February 2...
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                                                                 operations_tel  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            బి.హెచ్.ఈ.ఎల్  6,000 HP ఎలక్ట్రిక్ లోకోమోటివ్ ...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        భారత్ పెట్రోలియం కింది రిఫైనరీలను నిర్వహిస్తోం...
# కోల్ ఇండియా లిమిటెడ్                         CIL ప్రపంచంలోనే అతిపెద్ద బొగ్గు ఉత్పత్తి సంస్థ...
# గెయిల్ (ఇండియా) లిమిటెడ్                     గెయిల్ దాదాపు 13722 కి.మీ పొడవున ట్రంక్ పైప్‌ల...
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  HPCL అనేక రకాల పెట్రోలియం ఇంధనాలు, ప్రత్యేకతలన...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                        26 ఫిబ్రవరి 2011 న విలీనం పూర్తయిన తరువాత, ఇప్...
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                             wikidata  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            Q854820
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్            NaN
# కోల్ ఇండియా లిమిటెడ్                             NaN
# గెయిల్ (ఇండియా) లిమిటెడ్                         NaN
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్      NaN
# ...                                              ...
# హెచ్.టి.ఎల్ లిమిటెడ్                             NaN
# ఎయిర్ ఇండియా లిమిటెడ్                            NaN
# NaN                                              NaN
# NaN                                              NaN
# NaN                                              NaN
#
#                                                                                       wiki_url  \
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్            https://en.wikipedia.org/wiki/Bharat_Heavy_Ele...
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్        https://en.wikipedia.org/wiki/Bharat_Petroleum...
# కోల్ ఇండియా లిమిటెడ్                                  https://en.wikipedia.org/wiki/Coal_India
# గెయిల్ (ఇండియా) లిమిటెడ్                                    https://en.wikipedia.org/wiki/GAIL
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్  https://en.wikipedia.org/wiki/Hindustan_Petrol...
# ...                                                                                        ...
# హెచ్.టి.ఎల్ లిమిటెడ్                                                                       NaN
# ఎయిర్ ఇండియా లిమిటెడ్                          https://en.wikipedia.org/wiki/Air_India_Limited
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
#
#                                             zuba_url
# company_name_tel
# భారత్ హెవీ ఎలక్ట్రికల్స్ లిమిటెడ్                NaN
# భారత్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్            NaN
# కోల్ ఇండియా లిమిటెడ్                             NaN
# గెయిల్ (ఇండియా) లిమిటెడ్                         NaN
# హిందుస్తాన్ పెట్రోలియం కార్పొరేషన్ లిమిటెడ్      NaN
# ...                                              ...
# హెచ్.టి.ఎల్ లిమిటెడ్                             NaN
# ఎయిర్ ఇండియా లిమిటెడ్                            NaN
# NaN                                              NaN
# NaN                                              NaN
# NaN                                              NaN
#
# [360 rows x 116 columns]
