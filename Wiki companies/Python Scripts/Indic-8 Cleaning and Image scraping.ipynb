# %%
import pandas as pd
df1=pd.read_excel("C:/Users/bharg/Downloads/masterwiki.xlsx")
df2=pd.read_csv("C:/Users/bharg/Downloads/Cleaned_wiki.csv")
df1
# Out:
#      Unnamed: 0                    CIN                     Name  \
# 0             0  L61200GJ1985PLC007730      ఎ.బి.జి షిప్‌యార్డ్
# 1             1  U74899DL1994PTC059676           యాక్షన్ గ్రూప్
# 2             2  U62200TG2011PTC074087             ఎయిర్ కోస్టా
# 3             3  U62200OR2011PTC013043              ఎయిర్ ఒడిశా
# 4             4  U62200DL2007GOI161431             ఎయిర్ ఇండియా
# ..          ...                    ...                      ...
# 99           99  U72200KA2006PTC040763                   ఇంమోబి
# 100         100  U22100MH1996PLC096077                రిడీఫ్.కం
# 101         101  U29299MH1987PLC045446  రిలయన్స్ మీడియా వర్క్స్
# 102         102  U10102TG1920SGC000571  సింగరేణి కాలరీస్ కంపెనీ
# 103         103  U24237DL2006PLC144789         పతంజలి ఆయుర్వేద్
#
#                                Industry            Sector Headquarters  \
# 0                             పరిశ్రమలు       ఓడ నిర్మాణం   అహ్మదాబాద్
# ...

# %%
df2
# Out:
#      Unnamed: 0                    CIN  \
# 0             0  L01119TN1986PLC013473
# 1             1  L61200GJ1985PLC007730
# 2             2  L26940MH1936PLC002515
# 3             3  U74899DL1994PTC059676
# 4             4  U62200TG2011PTC074087
# ..          ...                    ...
# 429         429  U65191DL1901PLC002036
# 430         430  U65999WB1956PLC023304
# 431         431  L65191PN1943PLC007308
# 432         432  L65910MH1987PLC042961
# 433         433  L32102KA1945PLC020800
#
#                                                 Name           Industry  \
# 0                                      Aban Offshore          Oil & gas
# 1                                       ABG Shipyard        Industrials
# 2                                        ACC Limited        Industrials
# 3                                       Action Group       Conglomerate
# 4                                          Air Costa  Consumer services
# ...

# %%
list(zip(df2["CIN"],df2["Name"]))
# Out:
# [('L01119TN1986PLC013473', 'Aban Offshore'),
#  ('L61200GJ1985PLC007730', 'ABG Shipyard'),
#  ('L26940MH1936PLC002515', 'ACC Limited'),
#  ('U74899DL1994PTC059676', 'Action Group'),
#  ('U62200TG2011PTC074087', 'Air Costa'),
#  ('U62200OR2011PTC013043', 'Air Odisha'),
#  ('U62200DL2007GOI161431', 'Air India'),
#  ('U62100MH1971GOI015328', 'Air India Express'),
#  ('U18110CH1988PLC007928', 'Amartex'),
#  ('L26942GJ1981PLC004717', 'Ambuja Cements'),
#  ('U51909GJ1995PLC026934', 'Amul'),
#  ('L85110TN1979PLC008035', 'Apollo Hospitals'),
#  ('L25111KL1972PLC002449', 'Apollo Tyres'),
#  ('L72900MH2000PLC123841', 'Aptech'),
#  ('L36999HR1990PLC041175', 'Archies'),
#  ('U74899DL1995PLC071064', 'Arise India'),
#  ('L17119GJ1931PLC000093', 'Arvind'),
#  ('L34101TN1948PLC000105', 'Ashok Leyland'),
#  ('U11201GJ2002PLC041192', 'Asia MotorWorks'),
#  ('L24220MH1945PLC004598', 'Asian Paints Ltd'),
#  ('L65110GJ1993PLC020769', 'Axis Bank'),
#  ('L65993PN2007PLC130076', 'Bajaj Auto'),
# ...

# %%
l=[]
x=list(zip(df2["CIN"],df2["Name"]))
for cin in list(df1["CIN"]):
    for i,j in x:
        if i==cin:
            l.append(str(j))
print(len(l))
l
# Out:
# 104
# ['ABG Shipyard',
#  'Action Group',
#  'Air Costa',
#  'Air Odisha',
#  'Air India',
#  'Amartex',
#  'Amul',
#  'Arise India',
#  'Asia MotorWorks',
#  'Celkon',
#  'Deccan Charters',
#  'Dempo',
#  'Farida Group',
#  'Future Group',
#  "Haldiram's",
#  'Hero Cycles',
#  'iball',
#  'Ideal Jawa',
#  'Indian Express Limited',
#  'Indian Register of Shipping',
#  'Infosys BPM',
#  'Intex Technologies',
#  'Ittiam Systems',
#  'JetLite',
#  'Karbonn Mobiles',
#  'Knowlarity',
#  'Lava International',
#  'Mahindra Aerospace',
#  'Microland',
#  'Micromax Informatics',
#  'Milky Mist Dairy',
#  'Mistral Solutions',
#  'MKU (company)',
#  'Murugappa Group',
#  'Organic India',
#  'Oswald Labs',
#  'Paramount Airways',
#  'POSCO India',
#  'R K Global',
#  'Ranbaxy Laboratories',
#  'Reliance Digital',
#  'Reliance Entertainment',
#  'Reliance Fresh',
#  'Reliance Group',
#  'Reliance Health',
#  'Reliance Life Insurance',
#  'Reliance Retail',
#  'Royal Enfield',
# ...

# %%
df1["Name_Eng"]=l
df1
# Out:
#                        CIN                     Name  \
# 0    L61200GJ1985PLC007730      ఎ.బి.జి షిప్‌యార్డ్
# 1    U74899DL1994PTC059676           యాక్షన్ గ్రూప్
# 2    U62200TG2011PTC074087             ఎయిర్ కోస్టా
# 3    U62200OR2011PTC013043              ఎయిర్ ఒడిశా
# 4    U62200DL2007GOI161431             ఎయిర్ ఇండియా
# ..                     ...                      ...
# 99   U72200KA2006PTC040763                   ఇంమోబి
# 100  U22100MH1996PLC096077                రిడీఫ్.కం
# 101  U29299MH1987PLC045446  రిలయన్స్ మీడియా వర్క్స్
# 102  U10102TG1920SGC000571  సింగరేణి కాలరీస్ కంపెనీ
# 103  U24237DL2006PLC144789         పతంజలి ఆయుర్వేద్
#
#                                Industry            Sector Headquarters  \
# 0                             పరిశ్రమలు       ఓడ నిర్మాణం   అహ్మదాబాద్
# 1                              సమ్మేళనం                 -   న్యూఢిల్లీ
# 2                     వినియోగదారు సేవలు          విమానయాన      విజయవాడ
# ...

# %%
df1.to_excel("C:/Users/bharg/Downloads/masterwiki.xlsx")

# %%
l=[]
for logo in df["Logo"]:
    s=logo.split("/")
    if ord(s[-1][0])>=48 and ord(s[-1][0])<=57:
        l.append(s[-2])
    else:
        l.append(s[-1])
l
# Out:
# ['Logo-ABG_Shipyard.jpg',
#  '-',
#  'Air_Costa_Logo.jpg',
#  'Air_Odisha_logo.png',
#  'Air_India_Logo.svg',
#  '-',
#  'Amul_official_logo.svg',
#  'Arise_India_Ltd_-_Company_Logo.jpg',
#  'Asia_MotorWorks_logo.svg',
#  'Celkon.svg',
#  'DeccanChartersLogo.gif',
#  'DempoMiningCorporationLimitedLogo.gif',
#  '-',
#  'Future_Group_Logo.png',
#  'Haldiram%27s_Logo_SVG.svg',
#  '-',
#  '-',
#  'Yezdi_Logo.png',
#  'IndianExpressLimitedLogo.jpg',
#  'Indian_Register_of_Shipping_%28logo%29.png',
#  'Logo_of_Infosys_BPM.jpg',
#  'Intex_logo.png',
#  'Ittiam_logo_light_bg.svg',
#  'Jet_Lite_logo.svg',
#  'Karbonn-Logo.jpg',
#  'Knowlarity.png',
#  'Lava_International.svg',
#  'Mahindra_aerospace.webp',
#  'Microland.png',
#  'Micromax_Logo.svg',
#  'MilkyMist_Dairy.png',
#  'High_res_Mistral_logo.png',
#  '-',
#  'Murugappa_Group_Logo.svg',
#  '-',
#  'Oswald_Labs_Logo.svg',
#  'ParamountAirwaysLogo.png',
#  'POSCO_India.png',
#  'R_K_Global_logo.svg',
#  'Ranbaxy_Logo.svg',
# ...

# %%
df["Image"]=l
df
# Out:
#                        CIN                     Name  \
# 0    L61200GJ1985PLC007730      ఎ.బి.జి షిప్‌యార్డ్
# 1    U74899DL1994PTC059676           యాక్షన్ గ్రూప్
# 2    U62200TG2011PTC074087             ఎయిర్ కోస్టా
# 3    U62200OR2011PTC013043              ఎయిర్ ఒడిశా
# 4    U62200DL2007GOI161431             ఎయిర్ ఇండియా
# ..                     ...                      ...
# 99   U72200KA2006PTC040763                   ఇంమోబి
# 100  U22100MH1996PLC096077                రిడీఫ్.కం
# 101  U29299MH1987PLC045446  రిలయన్స్ మీడియా వర్క్స్
# 102  U10102TG1920SGC000571  సింగరేణి కాలరీస్ కంపెనీ
# 103  U24237DL2006PLC144789         పతంజలి ఆయుర్వేద్
#
#                                Industry            Sector Headquarters  \
# 0                             పరిశ్రమలు       ఓడ నిర్మాణం   అహ్మదాబాద్
# 1                              సమ్మేళనం                 -   న్యూఢిల్లీ
# 2                     వినియోగదారు సేవలు          విమానయాన      విజయవాడ
# ...

# %%
df.to_excel("C:/Users/bharg/Downloads/masterwiki.xlsx")

# %%
df.to_pickle("C:/Users/bharg/Downloads/masterwiki.pkl")
