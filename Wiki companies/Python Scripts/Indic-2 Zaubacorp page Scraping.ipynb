# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
ctr=0
cols = ['CIN','Company Name','Link','RoC','Company Status']
data_frame = pd.DataFrame(columns=cols)
n=0
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(8341,8500):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text) 
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
# 2910
#                         CIN  \
# 0                  AAL-3164
# 1     U74999DL2020PTC366178
# 2     U72300UP2011PTC046639
# 3     U24100GJ2012PTC072322
# 4     U51109BR2014PTC022109
# ...                     ...
# 2905  U01110KA2021PTC155690
# 2906  U74999KA2020PTC137433
# 2907  U65992TG1983PTC004210
# 2908  U01100KA2017PTC099353
# 2909               AAF-7414
#
#                                            Company Name  \
# 0                                      ANSHIKA CHEM LLP
# ...

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(8500,9000):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text) 
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   from ipykernel import kernelapp as app
# 8910
#                         CIN  \
# 0                  AAL-3164
# 1     U74999DL2020PTC366178
# 2     U72300UP2011PTC046639
# 3     U24100GJ2012PTC072322
# 4     U51109BR2014PTC022109
# ...                     ...
# 8905  U27101OR1983PLC001234
# 8906  U51420PN2021OPC200786
# 8907  U67120WB2007PTC116292
# 8908               AAQ-0254
# 8909  U18108RJ1987PTC004138
#
#                                            Company Name  \
# ...

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(9000,10000):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text) 
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   from ipykernel import kernelapp as app
# 15210
#                          CIN  \
# 0                   AAL-3164
# 1      U74999DL2020PTC366178
# 2      U72300UP2011PTC046639
# 3      U24100GJ2012PTC072322
# 4      U51109BR2014PTC022109
# ...                      ...
# 15205  U74999BR2017PTC034845
# 15206  U15312BR2009PTC015106
# 15207  U01210BR2018PTC039613
# 15208  U01403BR1988PTC003078
# 15209  U01409BR2018PTC039858
#
#                                             Company Name  \
# ...

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(10000,11000):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text) 
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   from ipykernel import kernelapp as app
# 36240
#                          CIN  \
# 0                   AAL-3164
# 1      U74999DL2020PTC366178
# 2      U72300UP2011PTC046639
# 3      U24100GJ2012PTC072322
# 4      U51109BR2014PTC022109
# ...                      ...
# 36235  U63030KL2019PTC060108
# 36236  U74999RJ2018PTC062427
# 36237  U29253MH2014PTC258463
# 36238  U74999JH2021PTC016539
# 36239  U32100KA2020PTC134034
#
#                                             Company Name  \
# ...

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(11000,13000):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text)
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   from ipykernel import kernelapp as app
# 57480
#                          CIN  \
# 0                   AAL-3164
# 1      U74999DL2020PTC366178
# 2      U72300UP2011PTC046639
# 3      U24100GJ2012PTC072322
# 4      U51109BR2014PTC022109
# ...                      ...
# 57475  U74999UP2019PTC116320
# 57476  U52100MH2014PTC257801
# 57477  U72900KA2020PTC132194
# 57478               AAB-7190
# 57479  U24232PB2001PLC024715
#
#                                             Company Name  \
# ...

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
for page in range(13000,13334):
    driver.get('https://www.zaubacorp.com/company-list/p-'+str(page)+'-company.html')
    tab= driver.find_elements(by = By.XPATH,value="//table[@class='table table-striped col-md-12 col-sm-12 col-xs-12']/tbody/tr/td")
    l=[]
    for val in tab:
        if len(l)==4:
            l.append(val.text)
            data_frame.loc[ctr] = l
            ctr+=1
            l=[]
        else:
            l.append(val.text)
            if len(l)==2:
                link = driver.find_element_by_link_text(val.text)
                l.append(link.get_attribute('href'))
print(ctr)
data_frame
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [C:\Users\bharg\.wdm\drivers\chromedriver\win32\99.0.4844.51\chromedriver.exe] found in cache
# c:\users\bharg\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   from ipykernel import kernelapp as app
# 57540
#                          CIN  \
# 0                   AAL-3164
# 1      U74999DL2020PTC366178
# 2      U72300UP2011PTC046639
# 3      U24100GJ2012PTC072322
# 4      U51109BR2014PTC022109
# ...                      ...
# 57535  U72909AP2011PTC075235
# 57536  U27100TG2008PLC058999
# 57537  U14200KL2020PTC065291
# 57538  U74999WB2012PTC176813
# 57539               AAZ-7927
#
#                                             Company Name  \
# ...

# %%
data_frame.to_csv("final.csv")
