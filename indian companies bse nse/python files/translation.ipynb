# %%
import pandas as pd
from deep_translator import GoogleTranslator
import numpy as np

# %%
data.to_csv("fullwikicmp.csv",index=False)

# %%
data=pd.read_csv("fullwikicmp.csv")

# %%
data1=pd.read_csv("wikicompanies.csv")

# %%
data['NSE code']=data1['NSE code']

# %%
len(data1['NSE code'])
# Out:
# 501

# %%
fata1=pd.read_csv("cin.csv")

# %%
fata1
# Out:
#      Unnamed: 0                    CIN
# 0             0  L74899DL1964GOI004281
# 1             1  L23220MH1952GOI008931
# 2             2  L23109WB1973GOI028844
# 3             3  L40200DL1984GOI018976
# 4             4  L23201MH1952GOI008858
# ..          ...                    ...
# 352         352  U45200MH2006PLC160164
# 353         353  U64200MH2003PLC143200
# 354         354  L23200GJ1969PLC001569
# 355         355  U93090TN1960PLC004355
# 356         356  U62100DL1992GOI048581
#
# [357 rows x 2 columns]

# %%
t=[]
for i in range(len(fata1.CIN)):
    print(fata1['CIN'][i])
    if fata1['CIN'][i] in l:
        t.append(True)
        print("yes")
    else:
        t.append(False)
        print("no")
# Out:
# L74899DL1964GOI004281
# yes
# L23220MH1952GOI008931
# yes
# L23109WB1973GOI028844
# yes
# L40200DL1984GOI018976
# yes
# L23201MH1952GOI008858
# yes
# L23201MH1959GOI011388
# yes
# L40101DL1975GOI007966
# yes
# L74899DL1993GOI054155
# yes
# L40101DL1989GOI038121
# yes
# L27109DL1973GOI006454
# yes
# L65910DL1986GOI024862
# yes
# L32309KA1954GOI000787
# yes
# L63011DL1988GOI030915
# yes
# L74899DL1965GOI004352
# yes
# L35301KA1963GOI001622
# yes
# L32101DL1986GOI023501
# yes
# L27203OR1981GOI000920
# yes
# L74899DL1960GOI003335
# no
# nan
# yes
# L93090TN1956GOI003507
# yes
# nan
# yes
# U27109AP1982GOI003404
# no
# L40101DL1969GOI005095
# yes
# nan
# yes
# nan
# yes
# U85110KA1992GOI013570
# no
# L15492WB1924GOI004835
# yes
# U10101JH1972GOI000918
# no
# L24292TG1970GOI001353
# yes
# L35202KA1964GOI001530
# yes
# U74899DL2000GOI107739
# no
# U27310WB1920GOI003601
# no
# U32109DL1974GOI007325
# no
# nan
# yes
# U10200JH1956GOI000581
# no
# U14292JH1975GOI001223
# no
# ...

# %%
len(t)
fata1['found']=t

# %%
fata1.to_csv("CIN.csv",index=False)

# %%
l=list(data['CIN'])

# %%
data
# Out:
#                                          Company  BSE code    NSE code  \
# 0                         Adani Enterprises Ltd.    512599    ADANIENT
# 1                        Adani Green Energy Ltd.    541450  ADANIGREEN
# 2     Adani Ports and Special Economic Zone Ltd.    532921  ADANIPORTS
# 3                           Adani Total Gas Ltd.    542066        ATGL
# 4                        Adani Transmission Ltd.    539254  ADANITRANS
# ...                                          ...       ...         ...
# 4105                          Zodiac Energy Ltd.    543416      ZODIAC
# 4106                         Zodiac-JRD-MKJ Ltd.    512587   ZODJRDMKJ
# 4107                        Zodiac Ventures Ltd.    503641         NaN
# 4108                   Zuari Agro Chemicals Ltd.    534742       ZUARI
# 4109                           Zuari Global Ltd.    500780   ZUARIGLOB
#
#               ISIN                  Sector                       Industry  \
# ...

# %%
Companyl=[]
for i in data['ISIN Description']:
    try:
        translated = GoogleTranslator(source='auto', target='te').translate(i)
        Companyl.append(translated)
        print(i,translated)
    except:
        Companyl.append(np.nan)

# %%
len(Companyl)

# %%
l=list(data['Industry'])

# %%
len(l)
# Out:
# 4110

# %%
s['Industry Tel'][2373:]=Companyl

# %%
s['ISIN Description']=data['ISIN Description']
s['ISIN Description Tel']=Companyl

# %%
s['Enterprise Value(Cr)']=data['Enterprise Value(Cr)']
s['Enterprise Value(Cr) Tel']=data['Enterprise Value(Cr)']

# %%
d={'Sector':l,'Sector Tel':Companyl}

# %%
s=pd.DataFrame(d)

# %%
s['Industry Tel'][2373:2379]
# Out:
# 2373    ఇతర వ్యవసాయ ఉత్పత్తులు
# 2374                       NaN
# 2375                       NaN
# 2376                       NaN
# 2377                       NaN
# 2378                       NaN
# Name: Industry Tel, dtype: object

# %%
s
# Out:
#                       Sector             Sector Tel  \
# 0                   Services                  సేవలు
# 1              Capital Goods        మూలధన వస్తువులు
# 2                   Services                  సేవలు
# 3                     Energy                  శక్తి
# 4                     Energy                  శక్తి
# ...                      ...                    ...
# 4105           Capital Goods        మూలధన వస్తువులు
# 4106  Consumer Discretionary  వినియోగదారుని విచక్షణ
# 4107               Financial                 ఆర్థిక
# 4108               Chemicals               రసాయనాలు
# 4109               Chemicals               రసాయనాలు
#
#                            Industry                 Industry Tel        Date  \
# 0                           Trading                    ట్రేడింగ్  08-04-2022
# 1                    Power Projects            పవర్ ప్రాజెక్ట్స్  08-04-2022
# 2              Marine Port Services      మెరైన్ పోర్ట్ సర్వీసెస్  08-04-2022
# ...

# %%
s['Description Tel'][1629:]=Companyl

# %%
s['REGISTERED_STATE']=data['REGISTERED_STATE']
s['REGISTERED_STATE Tel']=Companyl

# %%
s
# Out:
#                                             Description  \
# 0     Adani Enterprises Limited is a Public incorpor...
# 1     Adani Green Energy Limited is a Public incorpo...
# 2     Adani Ports And Special Economic Zone Limited ...
# 3     Adani Total Gas Limited is a Public incorporat...
# 4     Adani Transmission Limited is a Public incorpo...
# ...                                                 ...
# 4105  Zodiac Energy Limited is a Public incorporated...
# 4106  Zodiac-jrd-mkj Limited is a Public incorporate...
# 4107  Zodiac Ventures Limited is a Public incorporat...
# 4108  Zuari Agro Chemicals Limited is a Public incor...
# 4109  Zuari Global Limited is a Public incorporated ...
#
#                                         Description Tel  \
# 0     అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్ 02 మార్చి 1993న ...
# 1     అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్ అనేది 23 జనవరి 20...
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...
# 3     అదానీ టోటల్ గ్యాస్ లిమిటెడ్ అనేది 05 ఆగస్టు 20...
# ...

# %%
s.to_csv("tr_nse_bse_sector to enterprice.csv",index=False)

# %%
s['ISIN']=data['ISIN']
s['ISIN']=data['ISIN']

# %%
s
# Out:
#                                     Company_name  \
# 0                         Adani Enterprises Ltd.
# 1                        Adani Green Energy Ltd.
# 2     Adani Ports and Special Economic Zone Ltd.
# 3                           Adani Total Gas Ltd.
# 4                        Adani Transmission Ltd.
# ...                                          ...
# 4105                          Zodiac Energy Ltd.
# 4106                         Zodiac-JRD-MKJ Ltd.
# 4107                        Zodiac Ventures Ltd.
# 4108                   Zuari Agro Chemicals Ltd.
# 4109                           Zuari Global Ltd.
#
#                                         Company_name_tr  BSE code  \
# 0                         అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                          అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2     అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                           అదానీ టోటల్ గ్యాస్ లిమిటెడ్    542066
# ...

# %%
s.to_csv("tr_bse_nse_company_to_isin",index=False)

# %%
Companyl=[]
for i in data['BSE code']:
    try:
        translated = GoogleTranslator(source='auto', target='te').translate(i)
        Companyl.append(translated)
        print(i,translated)
    except:
        Companyl.append(np.nan)
