# %%
import pandas as pd

# %%
data=pd.read_csv("5.csv")
data
# Out:
#                                         Company  \
# 0                        Adani Enterprises Ltd.
# 1                       Adani Green Energy Ltd.
# 2    Adani Ports and Special Economic Zone Ltd.
# 3                       Adani Transmission Ltd.
# 4                             Asian Paints Ltd.
# ..                                          ...
# 496                           Vivimed Labs Ltd.
# 497                                    VTM Ltd.
# 498               Walchandnagar Industries Ltd.
# 499                               Weizmann Ltd.
# 500                              Zee Learn Ltd.
#
#                                                    url  \
# 0      https://en.wikipedia.org/wiki/Adani_Enterprises
# 1     https://en.wikipedia.org/wiki/Adani_Green_Energy
# 2    https://en.wikipedia.org/wiki/Adani_Ports_%26_SEZ
# 3     https://en.wikipedia.org/wiki/Adani_Transmission
# 4           https://en.wikipedia.org/wiki/Asian_Paints
# ...

# %%
len(data)
# Out:
# 501

# %%
data2=pd.read_csv("translated_bse_nse.csv")

# %%
data2

# %%
data3=data2[data2['url'].notna()]

# %%
data3['Awards']=data['Awards_Tel']
# Out:
# C:\Users\LAVAYANA\AppData\Local\Temp\ipykernel_6052\1512090971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['Awards']=data['Awards_Tel']

# %%
data3.to_csv("fullwikicmp.csv",index=False)

# %%
data3.shape
# Out:
# (501, 48)

# %%
df=pd.merge(data3,data,on='url',how='inner')

# %%
df
# Out:
#                                              Company_x  BSE code  \
# 0                        అదానీ ఎంటర్‌ప్రైజెస్ లిమిటెడ్    512599
# 1                         అదానీ గ్రీన్ ఎనర్జీ లిమిటెడ్    541450
# 2    అదానీ పోర్ట్స్ అండ్ స్పెషల్ ఎకనామిక్ జోన్ లిమి...    532921
# 3                        అదానీ ట్రాన్స్‌మిషన్ లిమిటెడ్    539254
# 4                            ఏషియన్ పెయింట్స్ లిమిటెడ్    500820
# ..                                                 ...       ...
# 500                                  Vivimed Labs Ltd.    532660
# 501                                      VTM లిమిటెడ్.    532893
# 502                వాల్‌చంద్‌నగర్ ఇండస్ట్రీస్ లిమిటెడ్    507410
# 503                                 వీజ్మాన్ లిమిటెడ్.    523011
# 504                                జీ లెర్న్ లిమిటెడ్.    533287
#
#             NSE code          ISIN           Sector                 Industry  \
# 0          అడానియంట్  INE423A01024            సేవలు                ట్రేడింగ్
# ...
